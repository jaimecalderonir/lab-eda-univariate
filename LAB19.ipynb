# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# %%
url = '/Users/Jaimecalderon/Downloads/amz_uk_price_prediction_dataset.csv'

# %%
df = pd.read_csv(url)

# %%
df['category'].describe()
# Out:
# count               2443651
# unique                  296
# top       Sports & Outdoors
# freq                 836265
# Name: category, dtype: object

# %%
frequency_table1 = df["category"].value_counts().head(5)

# %%
#The most popular categories are: Sports & Outdoors, Beauty, Handmade Clothing, Shoes & Accessories, Bath & Body and Birthday Gifts.

# %%
proportion_table = df['category'].value_counts(normalize=True).head(5)

# %%
proportion_table
# Out:
# category
# Sports & Outdoors                         0.342219
# Beauty                                    0.007903
# Handmade Clothing, Shoes & Accessories    0.007869
# Bath & Body                               0.007813
# Birthday Gifts                            0.007766
# Name: proportion, dtype: float64

# %%
proportion_table.plot.bar(x=frequency_table1.index, y=frequency_table1.values, legend = False);

# %%
fig, ax = plt.subplots()
proportion_table.plot.pie(autopct='%1.1f%%', startangle=750, colors=sns.color_palette("Set2"),ax=ax)
# Out:
# <Axes: ylabel='proportion'>

# %%
#Sports & outdoors dominate

# %%
df['price'].nunique()
# Out:
# 82916

# %%
df['price'].median()
# Out:
# 19.09

# %%
df['price'].mean()
# Out:
# 89.24380943923663

# %%
df['price'].mode()
# Out:
# 0    9.99
# Name: price, dtype: float64

# %%
#The mean is 89.24380943923663 and the mode is 9.99, this means that there are prices that are very high and because of that the mean rises.

# %%
var = df['price'].var()
max = df['price'].max()
min = df['price'].min()
std = df['price'].std()
range = df['price'].max() - df['price'].min()
quantiles_price = df['price'].quantile([0.25, 0.5, 0.75])
var, max, min, std, range, quantiles_price
# Out:
# (119445.48532256528,
#  100000.0,
#  0.0,
#  345.60886175352226,
#  100000.0,
#  0.25     9.99
#  0.50    19.09
#  0.75    45.99
#  Name: price, dtype: float64)

# %%
#There is a significance spread in prices because you can see that the min price is 0 and the max price is 100000. The range between prices is too big.

# %%
df['price'].describe()
# Out:
# count    2.443651e+06
# mean     8.924381e+01
# std      3.456089e+02
# min      0.000000e+00
# 25%      9.990000e+00
# 50%      1.909000e+01
# 75%      4.599000e+01
# max      1.000000e+05
# Name: price, dtype: float64

# %%
price = df['price']

# %%
price
# Out:
# 0          21.99
# 1          23.99
# 2          21.99
# 3          31.99
# 4          17.99
#            ...
# 2443646    22.34
# 2443647    97.99
# 2443648    52.99
# 2443649    79.99
# 2443650    53.99
# Name: price, Length: 2443651, dtype: float64

# %%
sns.histplot(df['price'], kde=False, bins=30, color="salmon")
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.boxplot(data = df['price'], color="lightblue")
# Out:
# <Axes: ylabel='price'>

# %%
#Yes there are products priced higher than the rest. We can see two outliers above 70.000.

# %%
mean =df['stars'].mean()
mode = df['stars'].mode()
mediana = df['stars'].median()

mean, mode, mediana
# Out:
# (2.152836472966065,
#  0    0.0
#  Name: stars, dtype: float64,
#  0.0)

# %%
#The common trend is to not leave a rating. The mean for rating is 2.1528.

# %%
var = df['stars'].var()
max = df['stars'].max()
min = df['stars'].min()
std = df['stars'].std()
range = df['stars'].max() - df['stars'].min()
quantiles_price = df['stars'].quantile([0.25, 0.5, 0.75])
var, max, min, std, range, quantiles_price
# Out:
# (4.81743402976196,
#  5.0,
#  0.0,
#  2.1948653785054697,
#  5.0,
#  0.25    0.0
#  0.50    0.0
#  0.75    4.4
#  Name: stars, dtype: float64)

# %%
#The ratings are consistent because either they are 0 or higher than 4, there is a wide variation between 0 and 4 in a range of 5.

# %%
skewness_price = df['stars'].skew()
kurtosis_price = df['stars'].kurtosis()

skewness_price, kurtosis_price
# Out:
# (0.08120735761080985, -1.9260061280432985)

# %%
#They lean toward lower values. The are no outliers and the distribution is not normal.

# %%
sns.histplot(df['stars'], kde=True, bins=30, color="salmon")
# Out:
# <Axes: xlabel='stars', ylabel='Count'>

# %%
#0 is the most repeated rating.
